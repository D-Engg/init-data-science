# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import other libraries if needed

# %%
# Import dataset "BankChurners.csv" which is shared in the assignment

df = pd.read_csv('..\BankChurners.csv')

# %%
# Print all the column names
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# df['Attrition_Flag'] = df['Attrition_Flag'].replace(['Attrited Customer', 'Existing Customer'], [1, 0])
# df.drop('CLIENTNUM', axis = 1)
#df.drop(df[df['Income_Category'] == 'Unknown'].index)

#df.iloc[np.where(df['Income_Category'] == 'Unknown')]

# %% [markdown]
# Below is the column descriptions available:
#
# Columns' Description:
#
# Clientnum : 	Client number. Unique identifier for the customer holding the account
#
# Attrition_Flag : Internal event (customer activity) variable - if the account is closed then 1 else 0
#
# Customer_Age : Customer's Age in Years
#
# Gender : M=Male, F=Female
#
# Dependent_count : Number of dependents
#
# Education_Level : Educational Qualification of the account holder (example: high school, college graduate, etc.)
#
# Marital_Status : Married, Single, Unknown
#
# Income_Category : Annual Income Category of the account holder (< $40K, $40K - 60K, $60K - $80K, $80K-$120K, > $120K, Unknown)
#
# Card_Category : Type of Card (Blue, Silver, Gold, Platinum)
#
# Months_on_book : 	Months on book (Time of Relationship)
#
# Total_Relationship_Count : Total no. of products held by the customer
#
# Months_Inactive_12_mon : No. of months inactive in the last 12 months
#
# Contacts_Count_12_mon : No. of Contacts in the last 12 months
#
# Credit_Limit : Credit Limit on the Credit Card
#
# Total_Revolving_Bal : Total Revolving Balance on the Credit Card
#
# Avg_Open_To_Buy : Open to Buy Credit Line (Average of last 12 months)
#
# Total_Amt_Chng_Q4_Q1 : Change in Transaction Amount (Q4 over Q1)
#
# Total_Trans_Amt : Total Transaction Amount (Last 12 months)
#
# Total_Trans_Ct : Total Transaction Count (Last 12 months)
#
# Total_Ct_Chng_Q4_Q1 : Change in Transaction Count (Q4 over Q1)
#
# Avg_Utilization_Ratio : Average Card Utilization Ratio

# %%
# Understand the columns and delete/drop all the irrelevant columns and retain/keep all the valid columns based 
# on your understanding

df.drop('CLIENTNUM', axis = 1, inplace = True)

# %%
df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
df.isnull().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  object
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  object
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
# ...

# %%
cat_cols = df.select_dtypes(include = 'object')
values = cat_cols.nunique()
print(values)
# Out:
# Attrition_Flag     2
# Gender             2
# Education_Level    7
# Marital_Status     4
# Income_Category    6
# Card_Category      4
# dtype: int64

# %%
df['Marital_Status'].unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
#Attrittion flag column being replaced with values [1, 0]

df['Attrition_Flag'] = df['Attrition_Flag'].replace(['Attrited Customer', 'Existing Customer'], [1, 0])

# %%
#Marital status as 'Unknown' is replaced with its mode

df.loc[df['Marital_Status'] == 'Unknown', 'Marital_Status'] = df['Marital_Status'].mode()[0]

# %%
#Marital status as 'Unknown' is replaced with its mode

df.loc[df['Education_Level'] == 'Unknown', 'Education_Level'] = df['Education_Level'].mode()[0]

# %%
# Do plotting as per the given instructions:

#  1. Plot box-plots for all the numerical attributes
#  2. Plot frequency plots/bar plots for all categorical attributes

# %%
#Boxplot for all the numerical columns

# %%
plt.boxplot(x = 'Months_on_book', data = df)
plt.show()

#Basic Analysis: Outliers exist

# %%
plt.boxplot(x = 'Customer_Age', data = df)
plt.show()

#Basic Analysis: Only 2 customer's age are outside of theoritical cut-off

# %%
plt.boxplot(x = 'Total_Relationship_Count', data = df)
plt.show()

#Basic Analysis: No outliers

# %%
plt.boxplot(x = 'Months_Inactive_12_mon', data = df)
plt.show()

#Basic Analysis: Looks like Q2 & Q3 are ovelapping with each other. Few outliers exist.

# %%
plt.boxplot(x = 'Contacts_Count_12_mon', data = df)
plt.show()

#Basic Analysis: Looks like Q2 & Q3 are ovelapping with each other. Few outliers exist.

# %%
plt.boxplot(x = 'Credit_Limit', data = df)
plt.show()

#Basic Analysis: Huge amount outliers exist and it is left skewed.

# %%
plt.boxplot(x = 'Total_Revolving_Bal', data = df)
plt.show()

#Basic Analysis: Data is right skewed.

# %%
plt.boxplot(x = 'Avg_Open_To_Buy', data = df)
plt.show()

#Basic Analysis: Huge amount outliers exist and it is left skewed.

# %%
plt.boxplot(x = 'Total_Amt_Chng_Q4_Q1', data = df)
plt.show()

#Basic Analysis: Huge amount outliers exist.

# %%
plt.boxplot(x = 'Total_Trans_Amt', data = df)
plt.show()

#Basic Analysis: Huge amount outliers exist and it is right skewed.

# %%
plt.boxplot(x = 'Total_Trans_Ct', data = df)
plt.show()

#Basic Analysis: Few outliers exist and it is slightly right skewed.

# %%
plt.boxplot(x = 'Avg_Utilization_Ratio', data = df)
plt.show()

#Basic Analysis: Data is left skewed.

# %%
# Barplots for all the categorical columns

# %%
plt.bar(x = 'Attrition_Flag', height = 0.6, data = df)
plt.show()

# %%
plt.bar(x = 'Gender', height = 0.2, width = 0.4, data = df)
plt.show()

# %%
plt.bar(x = 'Education_Level', height = 0.2, width = 0.4, data = df)
plt.xticks(rotation = 30)
plt.show()

# %%
plt.bar(x = 'Marital_Status', height = 0.2, width = 0.4, data = df)
plt.show()

# %%
plt.bar(x = df['Income_Category'], height = 0.2, width = 0.4)
plt.xticks(rotation = 30)
plt.show()

# %%
plt.bar(x = df['Card_Category'], height = 0.2, width = 0.4)
plt.show()

# %%
#Few plotting with combination of columns

# %%
sns.barplot(x = 'Card_Category', y ='Months_on_book', data = df, ci = None).set(ylabel = 'Months on Book', xlabel = 'Card Catagory')

plt.title('Card Category vs Months on Book')
# Out:
# Text(0.5, 1.0, 'Card Category vs Months on Book')

# %%
sns.barplot(x = 'Card_Category', y ='Credit_Limit', data = df, ci = None).set(ylabel = 'Credit Limit', xlabel = 'Card Catagory')

plt.title('Card Category vs Credit Limit')
# Out:
# Text(0.5, 1.0, 'Card Category vs Credit Limit')

# %%
sns.barplot(x = 'Card_Category', y ='Credit_Limit', hue = 'Gender', data = df, ci = None).set(ylabel = 'Credit Limit', xlabel = 'Card Catagory')

plt.title('Card Category vs Credit Limit')
# Out:
# Text(0.5, 1.0, 'Card Category vs Credit Limit')

# %%
sns.barplot(x = 'Card_Category', y ='Total_Revolving_Bal', hue = 'Gender', data = df, ci = None).set(ylabel = 'Total Revolving Balance', xlabel = 'Card Catagory')

plt.title('Card Category vs Total Revolving Balance')
# Out:
# Text(0.5, 1.0, 'Card Category vs Total Revolving Balance')

# %%
sns.barplot(x = 'Card_Category', y ='Total_Revolving_Bal', hue = 'Income_Category', data = df, ci = None).set(ylabel = 'Total Revolving Balance', xlabel = 'Card Catagory')
plt.title('Card Category vs Total Revolving Balance')
# Out:
# Text(0.5, 1.0, 'Card Category vs Total Revolving Balance')

# %%
ax = sns.barplot(x = 'Income_Category', y ='Customer_Age', hue = 'Card_Category', data = df, ci = None).set(ylabel = 'Customer Age', xlabel = 'Income Category')

plt.title('Income Catagory vs Customer Age')
plt.xticks(rotation = 30)
plt.show()

# %%
ax = sns.barplot(x = 'Income_Category', y ='Total_Trans_Amt', hue = 'Card_Category', data = df, ci = None).set(ylabel = 'Total Transaction (last 12 months)', xlabel = 'Income Category')

plt.xticks(rotation = 30)
plt.show()

# %%
sns.barplot(x = 'Marital_Status', y ='Total_Trans_Amt', hue = 'Card_Category', data = df, ci = None).set(ylabel = 'Total Transaction (last 12 months)', xlabel = 'Marital Status')
plt.title('Marital Status vs Total Transaction Amount')
# Out:
# Text(0.5, 1.0, 'Marital Status vs Total Transaction Amount')

# %%
ax = sns.barplot(x = 'Education_Level', y ='Total_Trans_Amt', hue = 'Card_Category', data = df, ci = None).set(ylabel = 'Total Transaction (last 12 months)', xlabel = 'Education Level')
plt.title('Education Level vs Total Transaction')
plt.xticks(rotation = 30)
plt.show()

# %%
sns.barplot(x = 'Income_Category', y ='Credit_Limit', hue = 'Gender', data = df, ci = None).set(ylabel = 'Credit Limit', xlabel = 'Income Catagory')
plt.xticks(rotation = 30)
plt.title('Income Category vs Credit Limit')
# Out:
# Text(0.5, 1.0, 'Income Category vs Credit Limit')

# %%
sns.boxplot(x= 'Total_Relationship_Count', y = 'Avg_Utilization_Ratio', data = df).set(ylabel = 'Avg. Utilization Ratio', xlabel = 'Total Relationship Count')
plt.title('Avg. Utilization Ratio vs Total Relationship Count')
# Out:
# Text(0.5, 1.0, 'Avg. Utilization Ratio vs Total Relationship Count')

# %%
sns.boxplot(x= 'Months_Inactive_12_mon', y = 'Avg_Utilization_Ratio', data = df).set(ylabel = 'Avg. Utilization Ratio', xlabel = 'Months Inactive (last 12 months)')
plt.title('Months Inactive vs Avg, Utilization Ratio')
# Out:
# Text(0.5, 1.0, 'Months Inactive vs Avg, Utilization Ratio')

# %%
# Try to write a function whcih should take two arguments: column_name and plot type (box-plot or bar-plot) 
# and automate the plotting based on the user

# def plotMyData(xaxis, yaxis, data, **params):
    
#     try:
#         if df[xaxis].dtype == object:
#             sns.barplot(x = xaxis, y = yaxis, hue = params.get('hue', None), data = data, ci = None).set(xlabel = params.get('xlabel', xaxis), ylabel = params.get('ylabel', yaxis))
#             plt.title(params.get('title', None))
#         else:
#             sns.boxplot(x= 'Months_Inactive_12_mon', y = 'Avg_Utilization_Ratio', data = df).set(xlabel = params.get('xlabel', xaxis), ylabel = params.get('ylabel', yaxis))
#             plt.title(params.get('title', None))
#     except Exception as e:
#         print('Check if you have passed the arguments correctly : ', e)


def myPlotting(column_name, pltType):
    try:
        if pltType.__contains__('bar'):
            plt.bar(x = df[column_name], height = 0.2, width = 0.4)
        else:
            plt.boxplot(x = df[column_name])
    except Exception as e:
        print('Some error happened while ploting: ', e)
    plt.show()

# %%
#plotMyData('Marital_Status', 'Total_Trans_Amt', df, xlabel = 'Marital Status', ylabel = 'Total Transaction (Last 12 Months)', hue = 'Card_Category', title = 'Marital Status vs Total Transaction Amt (Last 12 Months)')

#As of now, have included only xlabel, ylabel, hue and title as optional arguments.


myPlotting('Marital_Status', 'barplot')

# %%
myPlotting('Card_Category', 'bar-plot')

# %%
#plotMyData('Total_Relationship_Count', 'Avg_Utilization_Ratio', df)

myPlotting('Avg_Utilization_Ratio', 'boxplot')

# %%
# Basic Analysis:

# Write down your your observation about each attributes based on the plots

# %%
# month_on_book = df['Months_on_book'].sort_values()
# Q1 = month_on_book.quantile(0.25)
# Q3 = month_on_book.quantile(0.75)
# IQR = Q3 - Q1

#outlier = (month_on_book < (Q1 - 1.5 * IQR)) or (month_on_book > (Q3 + 1.5 * IQR))

# %%
#df.drop(df[(month_on_book < (Q1 - 1.5 * IQR)) | (month_on_book > (Q3 + 1.5 * IQR))].index, inplace = True)
